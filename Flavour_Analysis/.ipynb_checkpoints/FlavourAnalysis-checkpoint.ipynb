# %%
import csv
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import numpy
import scipy
import matplotlib
matplotlib.use('TkAgg')
#import pylab
import scipy.cluster.hierarchy as sch
numpy.set_printoptions(threshold=numpy.nan)

# %%
fema_terms_molecules = pd.read_csv("./fema_terms_compounds2.csv")
fema_terms_molecules = fema_terms_molecules.replace('Not Available', np.nan)
print(len(fema_terms_molecules))
na_terms = fema_terms_molecules.isnull().sum()
print(na_terms)
fema_terms_molecules = fema_terms_molecules.replace('Not Available', np.nan).dropna()

#count NA terms
fema_terms_molecules.head()
# Out:
# 2229
# pubchem_id               0
# fema_flavor_profile    600
# dtype: int64
#    pubchem_id fema_flavor_profile
# 1          47               Fruit
# 4          58              Savory
# 5          70               Fruit
# 7         119              Savory
# 8         125                Nuts

# %%
fema_dict=dict(zip(list(fema_terms_molecules['pubchem_id']), list(fema_terms_molecules['fema_flavor_profile'])))

# %%
fema_terms = []
fema_length = []
fema_cocc = []
new_fema_cocc = []
fft_list = []

for key in fema_dict:
    temp_list = []
    #print key
    temp_list = []
    x = fema_dict[key]
    #print x
    y = x.replace(", ",",")
    #print y
    y_list = y.replace("@",",").split(',')
    #print y_list
    for term in y_list:
        if(len(term.split(" "))<=2):
            fema_terms.append(term)
            temp_list.append(term)
            
    fft_list.append(','.join(temp_list))
    
    fema_length.append(len(y_list))
    fema_cocc.append((" ").join(x.split(', ')))
    new_fema_cocc.append(temp_list)
    
fema_set = set(fema_terms)
print(len(fema_set))
fema_term_count = []
with open('plot.csv', 'w+') as f:
    c = csv.writer(f)
    for word in fema_set:
        fema_term_count.append(fema_terms.count(word))
        x = fema_terms.count(word)
        c.writerow([word] + [x])
num_molecules = []
fema_count_set = set(fema_length)
for count in fema_count_set:
    num_molecules.append(fema_length.count(count)) 

print(len(fft_list))
#for i in fema_set:
#    print i
    
#print num_molecules
#print fema_count_set
#fema_set
#fema_count
#print((new_fema_cocc))
full_list = []
for i in new_fema_cocc:
    full_list.extend(i)
#print(len(full_list))
# Out:
# 248
# 1629

# %%
import numpy
import itertools
from collections import Counter
ranked_list = []

varnames = tuple(sorted(set(itertools.chain(*new_fema_cocc))))
expanded = [tuple(itertools.combinations(d, 2)) for d in new_fema_cocc]
expanded = itertools.chain(*expanded)

expanded = [tuple(sorted(d)) for d in expanded]

c = Counter(expanded)
table = numpy.zeros((len(varnames),len(varnames)), dtype=int)
normalised_ranked_list = []
for i, v1 in enumerate(varnames):
    for j, v2 in enumerate(varnames[i:]):        
        j = j + i 
        table[i, j] = c[v1, v2]
        table[j, i] = c[v1, v2]
        if(c[v1,v2]!=0):
            normalised_ranked_list.append([[i,j],float(c[v1,v2])/float(max(full_list.count(varnames[i]),full_list.count(varnames[j]))),[varnames[i],varnames[j]]])
            ranked_list.append([[i,j],float(c[v1,v2]),[varnames[i],varnames[j]]])
#for row in table:
 #   print(row)
pd.DataFrame(table)

sorted_ranked_list = sorted(ranked_list,key=lambda x: x[1],reverse=True)
sorted_ranked_list
sorted_normalised_ranked_list = sorted(normalised_ranked_list,key=lambda x: x[1],reverse=True)

# %%
sorted_normalised_ranked_list
# Out:
# [[[26, 195], 1.0, ['Boiled Cherries', 'Roasted Bread']],
#  [[35, 201], 1.0, ['Burnt Sugar', 'Roasted Pepper']],
#  [[63, 81], 1.0, ['Cotton', 'Fabric']],
#  [[83, 240], 1.0, ['Fatty', 'Waxy']],
#  [[86, 136], 1.0, ['Fir', 'Linoleum']],
#  [[96, 163], 1.0, ['Fruit Gum', 'Overripe Fruit']],
#  [[114, 217], 1.0, ['Hay', 'Straw']],
#  [[175, 197], 1.0, ['Petrol', 'Roasted Garlic']],
#  [[226, 227], 1.0, ['Tomato', 'Tomato Leaf']],
#  [[238, 244], 1.0, ['Watermelon', 'Wet Wool']],
#  [[61, 145], 0.8076923076923077, ['Cool', 'Mint']],
#  [[17, 84], 0.6666666666666666, ['Basil', 'Fennel']],
#  [[0, 234], 0.5, ['Acid', 'Vinegar']],
#  [[9, 50], 0.5, ['Arise', 'Cinnamon']],
#  [[12, 232], 0.5, ['Astringent', 'Vanilla']],
#  [[14, 30], 0.5, ['Baked Potatoes', 'Bread']],
#  [[17, 42], 0.5, ['Basil', 'Caraway']],
#  [[19, 111], 0.5, ['Bell Pepper', 'Green Pepper']],
#  [[24, 233], 0.5, ['Blue Cheese', 'Vegetable']],
#  [[30, 133], 0.5, ['Bread', 'Licorice']],
#  [[30, 236], 0.5, ['Bread', 'Walnut']],
#  [[35, 49], 0.5, ['Burnt Sugar', 'Cherry']],
#  [[38, 46], 0.5, ['Camomile', 'Celery']],
#  [[42, 84], 0.5, ['Caraway', 'Fennel']],
#  [[46, 190], 0.5, ['Celery', 'Red Fruit']],
#  [[47, 238], 0.5, ['Cereal', 'Watermelon']],
#  [[47, 244], 0.5, ['Cereal', 'Wet Wool']],
#  [[49, 201], 0.5, ['Cherry', 'Roasted Pepper']],
#  [[64, 140], 0.5, ['Cotton Candy', 'Maple']],
#  [[76, 200], 0.5, ['Durian', 'Roasted Onion']],
#  [[109, 231], 0.5, ['Green Fruit', 'Unripe Banana']],
#  [[120, 153], 0.5, ['Horseradish', 'Mustard']],
#  [[122, 170], 0.5, ['Iron Scorch', 'Peanut Butter']],
#  [[128, 215], 0.5, ['Leather', 'Stable']],
#  [[129, 143], 0.5, ['Leek', 'Meat Broth']],
#  [[132, 184], 0.5, ['Lettuce', 'Prune']],
#  [[133, 236], 0.5, ['Licorice', 'Walnut']],
#  [[160, 221], 0.5, ['Orange Peel', 'Tallow']],
#  [[161, 242], 0.5, ['Organic', 'Wet Earth']],
#  [[164, 242], 0.5, ['Oxidized', 'Wet Earth']],
#  [[196, 224], 0.5, ['Roasted Corn', 'Toasted Cereal']],
#  [[23, 44], 0.45454545454545453, ['Black Currant', 'Cat']],
#  [[23, 103], 0.45454545454545453, ['Black Currant', 'Grapefruit']],
#  [[29, 102], 0.4, ['Brandy', 'Grape']],
#  [[103, 139], 0.375, ['Grapefruit', 'Mango']],
#  [[37, 99], 0.35714285714285715, ['Cabbage', 'Garlic']],
#  [[1, 40], 0.3333333333333333, ['Alcohol', 'Candy']],
#  [[7, 96], 0.3333333333333333, ['Apple Peel', 'Fruit Gum']],
#  [[7, 163], 0.3333333333333333, ['Apple Peel', 'Overripe Fruit']],
#  [[7, 180], 0.3333333333333333, ['Apple Peel', 'Plum']],
#  [[17, 21], 0.3333333333333333, ['Basil', 'Bitter']],
#  [[20, 100], 0.3333333333333333, ['Berry', 'Geranium']],
#  [[20, 175], 0.3333333333333333, ['Berry', 'Petrol']],
#  [[20, 197], 0.3333333333333333, ['Berry', 'Roasted Garlic']],
#  [[21, 42], 0.3333333333333333, ['Bitter', 'Caraway']],
#  [[21, 84], 0.3333333333333333, ['Bitter', 'Fennel']],
#  [[22, 34], 0.3333333333333333, ['Bitter Almond', 'Burnt Matches']],
#  [[22, 35], 0.3333333333333333, ['Bitter Almond', 'Burnt Sugar']],
#  [[22, 49], 0.3333333333333333, ['Bitter Almond', 'Cherry']],
#  [[22, 201], 0.3333333333333333, ['Bitter Almond', 'Roasted Pepper']],
#  [[26, 148], 0.3333333333333333, ['Boiled Cherries', 'Moss']],
#  [[28, 166], 0.3333333333333333, ['Box Tree', 'Passion Fruit']],
#  [[39, 92], 0.3333333333333333, ['Camphor', 'Fragrant']],
#  [[39, 181], 0.3333333333333333, ['Camphor', 'Polish']],
#  [[43, 200], 0.3333333333333333, ['Carbide', 'Roasted Onion']],
#  [[47, 72], 0.3333333333333333, ['Cereal', 'Deep Fried']],
#  [[58, 221], 0.3333333333333333, ['Cooked Meat', 'Tallow']],
#  [[58, 222], 0.3333333333333333, ['Cooked Meat', 'Thiamin']],
#  [[60, 212], 0.3333333333333333, ['Cooked potato', 'Soy']],
#  [[62, 72], 0.3333333333333333, ['Coriander', 'Deep Fried']],
#  [[62, 126], 0.3333333333333333, ['Coriander', 'Lavender']],
#  [[62, 164], 0.3333333333333333, ['Coriander', 'Oxidized']],
#  [[64, 68], 0.3333333333333333, ['Cotton Candy', 'Curry']],
#  [[65, 111], 0.3333333333333333, ['Creamy', 'Green Pepper']],
#  [[65, 179], 0.3333333333333333, ['Creamy', 'Pleasant']],
#  [[68, 140], 0.3333333333333333, ['Curry', 'Maple']],
#  [[72, 164], 0.3333333333333333, ['Deep Fried', 'Oxidized']],
#  [[72, 238], 0.3333333333333333, ['Deep Fried', 'Watermelon']],
#  [[72, 244], 0.3333333333333333, ['Deep Fried', 'Wet Wool']],
#  [[74, 247], 0.3333333333333333, ['Dry Fish', 'Yeast']],
#  [[77, 225], 0.3333333333333333, ['Dust', 'Toasted Nut']],
#  [[100, 131], 0.3333333333333333, ['Geranium', 'Lemon Peel']],
#  [[100, 166], 0.3333333333333333, ['Geranium', 'Passion Fruit']],
#  [[107, 124], 0.3333333333333333, ['Green Apple', 'Kiwi']],
#  [[109, 110], 0.3333333333333333, ['Green Fruit', 'Green Leaf']],
#  [[109, 127], 0.3333333333333333, ['Green Fruit', 'Leaf']],
#  [[110, 231], 0.3333333333333333, ['Green Leaf', 'Unripe Banana']],
#  [[131, 166], 0.3333333333333333, ['Lemon Peel', 'Passion Fruit']],
#  [[132, 235], 0.3333333333333333, ['Lettuce', 'Violet']],
#  [[144, 180], 0.3333333333333333, ['Melon', 'Plum']],
#  [[148, 195], 0.3333333333333333, ['Moss', 'Roasted Bread']],
#  [[149, 237], 0.3333333333333333, ['Mothball', 'Warm']],
#  [[160, 172], 0.3333333333333333, ['Orange Peel', 'Penetrating']],
#  [[167, 247], 0.3333333333333333, ['Pastry', 'Yeast']],
#  [[172, 221], 0.3333333333333333, ['Penetrating', 'Tallow']],
#  [[184, 235], 0.3333333333333333, ['Prune', 'Violet']],
#  [[193, 199], 0.3333333333333333, ['Roast Beef', 'Roasted Nut']],
#  [[208, 212], 0.3333333333333333, ['Silage', 'Soy']],
#  [[236, 237], 0.3333333333333333, ['Walnut', 'Warm']],
#  [[5, 16], 0.3181818181818182, ['Apple', 'Banana']],
#  [[53, 192], 0.3, ['Cocoa', 'Roast']],
#  [[8, 178], 0.29411764705882354, ['Apricot', 'Pineapple']],
#  [[39, 152], 0.2857142857142857, ['Camphor', 'Must']],
#  [[92, 181], 0.2857142857142857, ['Fragrant', 'Polish']],
#  [[158, 219], 0.28125, ['Onion', 'Sulfur']],
#  [[182, 192], 0.2777777777777778, ['Popcorn', 'Roast']],
#  [[5, 178], 0.2727272727272727, ['Apple', 'Pineapple']],
#  [[23, 139], 0.2727272727272727, ['Black Currant', 'Mango']],
#  [[33, 41], 0.2727272727272727, ['Burnt', 'Caramel']],
#  [[39, 78], 0.26666666666666666, ['Camphor', 'Earth']],
#  [[0, 207], 0.25, ['Acid', 'Sharp']],
#  [[10, 102], 0.25, ['Aromatic', 'Grape']],
#  [[28, 139], 0.25, ['Box Tree', 'Mango']],
#  [[37, 219], 0.25, ['Cabbage', 'Sulfur']],
#  [[42, 213], 0.25, ['Caraway', 'Spearmint']],
#  [[42, 223], 0.25, ['Caraway', 'Thyme']],
#  [[45, 207], 0.25, ['Cedarwood', 'Sharp']],
#  [[52, 68], 0.25, ['Clove', 'Curry']],
#  [[58, 143], 0.25, ['Cooked Meat', 'Meat Broth']],
#  [[76, 129], 0.25, ['Durian', 'Leek']],
#  [[76, 139], 0.25, ['Durian', 'Mango']],
#  [[94, 160], 0.25, ['Fried', 'Orange Peel']],
#  [[94, 172], 0.25, ['Fried', 'Penetrating']],
#  [[94, 198], 0.25, ['Fried', 'Roasted Meat']],
#  [[94, 221], 0.25, ['Fried', 'Tallow']],
#  [[99, 219], 0.25, ['Garlic', 'Sulfur']],
#  [[103, 228], 0.25, ['Grapefruit', 'Tropical Fruit']],
#  [[104, 110], 0.25, ['Grass', 'Green Leaf']],
#  [[105, 129], 0.25, ['Gravy', 'Leek']],
#  [[105, 143], 0.25, ['Gravy', 'Meat Broth']],
#  [[107, 218], 0.25, ['Green Apple', 'Strawberry']],
#  [[119, 129], 0.25, ['Hop', 'Leek']],
#  [[119, 173], 0.25, ['Hop', 'Pepper']],
#  [[129, 173], 0.25, ['Leek', 'Pepper']],
#  [[129, 200], 0.25, ['Leek', 'Roasted Onion']],
#  [[129, 210], 0.25, ['Leek', 'Soup']],
#  [[139, 166], 0.25, ['Mango', 'Passion Fruit']],
#  [[139, 191], 0.25, ['Mango', 'Rhubarb']],
#  [[143, 210], 0.25, ['Meat Broth', 'Soup']],
#  [[143, 221], 0.25, ['Meat Broth', 'Tallow']],
#  [[173, 234], 0.25, ['Pepper', 'Vinegar']],
#  [[174, 207], 0.25, ['Peppermint', 'Sharp']],
#  [[118, 202], 0.23809523809523808, ['Honey', 'Rose']],
#  [[36, 48], 0.23529411764705882, ['Butter', 'Cheese']],
#  [[8, 168], 0.23076923076923078, ['Apricot', 'Peach']],
#  [[2, 137], 0.2222222222222222, ['Almond', 'Malt']],
#  [[52, 176], 0.2222222222222222, ['Clove', 'Phenol']],
#  [[115, 194], 0.2222222222222222, ['Hazelnut', 'Roasted']],
#  [[170, 194], 0.2222222222222222, ['Peanut Butter', 'Roasted']],
#  [[37, 158], 0.21739130434782608, ['Cabbage', 'Onion']],
#  [[16, 171], 0.21428571428571427, ['Banana', 'Pear']],
#  [[7, 29], 0.2, ['Apple Peel', 'Brandy']],
#  [[10, 29], 0.2, ['Aromatic', 'Brandy']],
#  [[28, 44], 0.2, ['Box Tree', 'Cat']],
#  [[29, 96], 0.2, ['Brandy', 'Fruit Gum']],
#  [[29, 163], 0.2, ['Brandy', 'Overripe Fruit']],
#  [[44, 142], 0.2, ['Cat', 'Meat']],
#  [[53, 115], 0.2, ['Cocoa', 'Hazelnut']],
#  [[67, 206], 0.2, ['Cucumber', 'Seaweed']],
#  [[78, 151], 0.2, ['Earth', 'Mushroom']],
#  [[78, 152], 0.2, ['Earth', 'Must']],
#  [[78, 183], 0.2, ['Earth', 'Potato']],
#  [[79, 107], 0.2, ['Ester', 'Green Apple']],
#  [[79, 124], 0.2, ['Ester', 'Kiwi']],
#  [[90, 118], 0.19047619047619047, ['Flower', 'Honey']],
#  [[5, 218], 0.18181818181818182, ['Apple', 'Strawberry']],
#  [[23, 28], 0.18181818181818182, ['Black Currant', 'Box Tree']],
#  [[23, 142], 0.18181818181818182, ['Black Currant', 'Meat']],
#  [[23, 228], 0.18181818181818182, ['Black Currant', 'Tropical Fruit']],
#  [[33, 137], 0.18181818181818182, ['Burnt', 'Malt']],
#  [[48, 211], 0.17647058823529413, ['Cheese', 'Sour']],
#  [[152, 246], 0.17647058823529413, ['Must', 'Wood']],
#  [[51, 157], 0.17391304347826086, ['Citrus', 'Oil']],
#  [[129, 158], 0.17391304347826086, ['Leek', 'Onion']],
#  [[13, 204], 0.16666666666666666, ['Baked', 'Rum']],
#  [[20, 204], 0.16666666666666666, ['Berry', 'Rum']],
#  [[30, 115], 0.16666666666666666, ['Bread', 'Hazelnut']],
#  [[39, 39], 0.16666666666666666, ['Camphor', 'Camphor']],
#  [[47, 115], 0.16666666666666666, ['Cereal', 'Hazelnut']],
#  [[60, 199], 0.16666666666666666, ['Cooked potato', 'Roasted Nut']],
#  [[67, 239], 0.16666666666666666, ['Cucumber', 'Wax']],
#  [[85, 115], 0.16666666666666666, ['Fermented', 'Hazelnut']],
#  [[87, 153], 0.16666666666666666, ['Fish', 'Mustard']],
#  [[87, 159], 0.16666666666666666, ['Fish', 'Orange']],
#  [[87, 164], 0.16666666666666666, ['Fish', 'Oxidized']],
#  [[87, 242], 0.16666666666666666, ['Fish', 'Wet Earth']],
#  [[115, 133], 0.16666666666666666, ['Hazelnut', 'Licorice']],
#  [[115, 170], 0.16666666666666666, ['Hazelnut', 'Peanut Butter']],
#  [[115, 216], 0.16666666666666666, ['Hazelnut', 'Stinging Nettle']],
#  [[115, 236], 0.16666666666666666, ['Hazelnut', 'Walnut']],
#  [[122, 204], 0.16666666666666666, ['Iron Scorch', 'Rum']],
#  [[141, 199], 0.16666666666666666, ['Marshmallow', 'Roasted Nut']],
#  [[159, 239], 0.16666666666666666, ['Orange', 'Wax']],
#  [[170, 204], 0.16666666666666666, ['Peanut Butter', 'Rum']],
#  [[82, 157], 0.16216216216216217, ['Fat', 'Oil']],
#  [[154, 192], 0.15789473684210525, ['Nut', 'Roast']],
#  [[36, 41], 0.15384615384615385, ['Butter', 'Caramel']],
#  [[36, 211], 0.15384615384615385, ['Butter', 'Sour']],
#  [[168, 180], 0.15384615384615385, ['Peach', 'Plum']],
#  [[48, 185], 0.15151515151515152, ['Cheese', 'Pungent']],
#  [[185, 219], 0.15151515151515152, ['Pungent', 'Sulfur']],
#  [[51, 93], 0.15, ['Citrus', 'Fresh']],
#  [[51, 151], 0.15, ['Citrus', 'Mushroom']],
#  [[53, 55], 0.15, ['Cocoa', 'Coffee']],
#  [[53, 137], 0.15, ['Cocoa', 'Malt']],
#  [[4, 84], 0.14285714285714285, ['Anise', 'Fennel']],
#  [[4, 133], 0.14285714285714285, ['Anise', 'Licorice']],
#  [[11, 183], 0.14285714285714285, ['Asparagus', 'Potato']],
#  [[16, 101], 0.14285714285714285, ['Banana', 'Glue']],
#  [[16, 104], 0.14285714285714285, ['Banana', 'Grass']],
#  [[21, 137], 0.14285714285714285, ['Bitter', 'Malt']],
#  [[22, 137], 0.14285714285714285, ['Bitter Almond', 'Malt']],
#  [[29, 171], 0.14285714285714285, ['Brandy', 'Pear']],
#  [[35, 137], 0.14285714285714285, ['Burnt Sugar', 'Malt']],
#  [[40, 228], 0.14285714285714285, ['Candy', 'Tropical Fruit']],
#  [[44, 130], 0.14285714285714285, ['Cat', 'Lemon']],
#  [[45, 177], 0.14285714285714285, ['Cedarwood', 'Pine']],
#  [[46, 171], 0.14285714285714285, ['Celery', 'Pear']],
#  [[49, 137], 0.14285714285714285, ['Cherry', 'Malt']],
#  [[54, 56], 0.14285714285714285, ['Coconut', 'Cognac']],
#  [[54, 72], 0.14285714285714285, ['Coconut', 'Deep Fried']],
#  [[62, 130], 0.14285714285714285, ['Coriander', 'Lemon']],
#  [[65, 228], 0.14285714285714285, ['Creamy', 'Tropical Fruit']],
#  [[76, 228], 0.14285714285714285, ['Durian', 'Tropical Fruit']],
#  [[77, 92], 0.14285714285714285, ['Dust', 'Fragrant']],
#  [[85, 137], 0.14285714285714285, ['Fermented', 'Malt']],
#  [[86, 177], 0.14285714285714285, ['Fir', 'Pine']],
#  [[88, 137], 0.14285714285714285, ['Fish Oil', 'Malt']],
#  [[92, 121], 0.14285714285714285, ['Fragrant', 'Hot Milk']],
#  [[92, 147], 0.14285714285714285, ['Fragrant', 'Mold']],
#  [[92, 152], 0.14285714285714285, ['Fragrant', 'Must']],
#  [[92, 179], 0.14285714285714285, ['Fragrant', 'Pleasant']],
#  [[94, 183], 0.14285714285714285, ['Fried', 'Potato']],
#  [[101, 171], 0.14285714285714285, ['Glue', 'Pear']],
#  [[102, 171], 0.14285714285714285, ['Grape', 'Pear']],
#  [[112, 183], 0.14285714285714285, ['Greenery', 'Potato']],
#  [[115, 137], 0.14285714285714285, ['Hazelnut', 'Malt']],
#  [[115, 182], 0.14285714285714285, ['Hazelnut', 'Popcorn']],
#  [[126, 130], 0.14285714285714285, ['Lavender', 'Lemon']],
#  [[136, 177], 0.14285714285714285, ['Linoleum', 'Pine']],
#  [[137, 201], 0.14285714285714285, ['Malt', 'Roasted Pepper']],
#  [[139, 228], 0.14285714285714285, ['Mango', 'Tropical Fruit']],
#  [[152, 181], 0.14285714285714285, ['Must', 'Polish']],
#  [[152, 183], 0.14285714285714285, ['Must', 'Potato']],
#  [[152, 194], 0.14285714285714285, ['Must', 'Roasted']],
#  [[171, 190], 0.14285714285714285, ['Pear', 'Red Fruit']],
#  [[177, 181], 0.14285714285714285, ['Pine', 'Polish']],
#  [[177, 207], 0.14285714285714285, ['Pine', 'Sharp']],
#  [[179, 228], 0.14285714285714285, ['Pleasant', 'Tropical Fruit']],
#  [[182, 199], 0.14285714285714285, ['Popcorn', 'Roasted Nut']],
#  [[183, 198], 0.14285714285714285, ['Potato', 'Roasted Meat']],
#  [[183, 212], 0.14285714285714285, ['Potato', 'Soy']],
#  [[188, 228], 0.14285714285714285, ['Radish', 'Tropical Fruit']],
#  [[200, 228], 0.14285714285714285, ['Roasted Onion', 'Tropical Fruit']],
#  [[5, 171], 0.13636363636363635, ['Apple', 'Pear']],
#  [[48, 157], 0.13043478260869565, ['Cheese', 'Oil']],
#  [[143, 158], 0.13043478260869565, ['Meat Broth', 'Onion']],
#  [[8, 29], 0.125, ['Apricot', 'Brandy']],
#  [[8, 209], 0.125, ['Apricot', 'Solvent']],
#  [[11, 151], 0.125, ['Asparagus', 'Mushroom']],
#  [[28, 103], 0.125, ['Box Tree', 'Grapefruit']],
#  [[44, 103], 0.125, ['Cat', 'Grapefruit']],
#  [[55, 91], 0.125, ['Coffee', 'Foxy']],
#  [[55, 146], 0.125, ['Coffee', 'Mocha']],
#  [[55, 193], 0.125, ['Coffee', 'Roast Beef']],
#  [[55, 198], 0.125, ['Coffee', 'Roasted Meat']],
#  [[55, 199], 0.125, ['Coffee', 'Roasted Nut']],
#  [[67, 151], 0.125, ['Cucumber', 'Mushroom']],
#  [[71, 104], 0.125, ['Dandelion', 'Grass']],
#  [[77, 104], 0.125, ['Dust', 'Grass']],
#  [[79, 218], 0.125, ['Ester', 'Strawberry']],
#  [[94, 151], 0.125, ['Fried', 'Mushroom']],
#  [[103, 130], 0.125, ['Grapefruit', 'Lemon']],
#  [[103, 166], 0.125, ['Grapefruit', 'Passion Fruit']],
#  [[103, 191], 0.125, ['Grapefruit', 'Rhubarb']],
#  [[104, 109], 0.125, ['Grass', 'Green Fruit']],
#  [[104, 171], 0.125, ['Grass', 'Pear']],
#  [[104, 231], 0.125, ['Grass', 'Unripe Banana']],
#  [[124, 218], 0.125, ['Kiwi', 'Strawberry']],
#  [[148, 151], 0.125, ['Moss', 'Mushroom']],
#  [[151, 173], 0.125, ['Mushroom', 'Pepper']],
#  [[151, 183], 0.125, ['Mushroom', 'Potato']],
#  [[151, 218], 0.125, ['Mushroom', 'Strawberry']],
#  [[173, 218], 0.125, ['Pepper', 'Strawberry']],
#  [[190, 218], 0.125, ['Red Fruit', 'Strawberry']],
#  [[204, 218], 0.125, ['Rum', 'Strawberry']],
#  [[185, 211], 0.12121212121212122, ['Pungent', 'Sour']],
#  [[29, 178], 0.11764705882352941, ['Brandy', 'Pineapple']],
#  [[33, 48], 0.11764705882352941, ['Burnt', 'Cheese']],
#  [[33, 246], 0.11764705882352941, ['Burnt', 'Wood']],
#  [[37, 48], 0.11764705882352941, ['Cabbage', 'Cheese']],
#  [[48, 99], 0.11764705882352941, ['Cheese', 'Garlic']],
#  [[78, 246], 0.11764705882352941, ['Earth', 'Wood']],
#  [[168, 178], 0.11764705882352941, ['Peach', 'Pineapple']],
#  [[178, 218], 0.11764705882352941, ['Pineapple', 'Strawberry']],
#  [[0, 211], 0.1111111111111111, ['Acid', 'Sour']],
#  [[2, 4], 0.1111111111111111, ['Almond', 'Anise']],
#  [[2, 14], 0.1111111111111111, ['Almond', 'Baked Potatoes']],
#  [[2, 21], 0.1111111111111111, ['Almond', 'Bitter']],
#  [[2, 30], 0.1111111111111111, ['Almond', 'Bread']],
#  [[2, 55], 0.1111111111111111, ['Almond', 'Coffee']],
#  [[2, 85], 0.1111111111111111, ['Almond', 'Fermented']],
#  [[2, 91], 0.1111111111111111, ['Almond', 'Foxy']],
#  [[2, 115], 0.1111111111111111, ['Almond', 'Hazelnut']],
#  [[2, 174], 0.1111111111111111, ['Almond', 'Peppermint']],
#  [[2, 176], 0.1111111111111111, ['Almond', 'Phenol']],
#  [[2, 194], 0.1111111111111111, ['Almond', 'Roasted']],
#  [[2, 207], 0.1111111111111111, ['Almond', 'Sharp']],
#  [[8, 211], 0.1111111111111111, ['Apricot', 'Sour']],
#  [[43, 203], 0.1111111111111111, ['Carbide', 'Rubber']],
#  [[49, 211], 0.1111111111111111, ['Cherry', 'Sour']],
#  [[66, 176], 0.1111111111111111, ['Cresol', 'Phenol']],
#  [[78, 192], 0.1111111111111111, ['Earth', 'Roast']],
#  [[85, 211], 0.1111111111111111, ['Fermented', 'Sour']],
#  [[122, 194], 0.1111111111111111, ['Iron Scorch', 'Roasted']],
#  [[128, 176], 0.1111111111111111, ['Leather', 'Phenol']],
#  [[142, 192], 0.1111111111111111, ['Meat', 'Roast']],
#  [[151, 203], 0.1111111111111111, ['Mushroom', 'Rubber']],
#  [[166, 203], 0.1111111111111111, ['Passion Fruit', 'Rubber']],
#  [[173, 203], 0.1111111111111111, ['Pepper', 'Rubber']],
#  [[176, 215], 0.1111111111111111, ['Phenol', 'Stable']],
#  [[182, 194], 0.1111111111111111, ['Popcorn', 'Roasted']],
#  [[183, 192], 0.1111111111111111, ['Potato', 'Roast']],
#  [[183, 194], 0.1111111111111111, ['Potato', 'Roasted']],
#  [[192, 204], 0.1111111111111111, ['Roast', 'Rum']],
#  [[194, 203], 0.1111111111111111, ['Roasted', 'Rubber']],
#  [[194, 204], 0.1111111111111111, ['Roasted', 'Rum']],
#  [[200, 203], 0.1111111111111111, ['Roasted Onion', 'Rubber']],
#  [[203, 218], 0.1111111111111111, ['Rubber', 'Strawberry']],
#  [[211, 234], 0.1111111111111111, ['Sour', 'Vinegar']],
#  [[51, 82], 0.10810810810810811, ['Citrus', 'Fat']],
#  [[82, 185], 0.10810810810810811, ['Fat', 'Pungent']],
#  [[5, 117], 0.10714285714285714, ['Apple', 'Herb']],
#  [[16, 117], 0.10714285714285714, ['Banana', 'Herb']],
#  [[104, 117], 0.10714285714285714, ['Grass', 'Herb']],
#  [[117, 157], 0.10714285714285714, ['Herb', 'Oil']],
#  [[154, 182], 0.10526315789473684, ['Nut', 'Popcorn']],
#  [[154, 183], 0.10526315789473684, ['Nut', 'Potato']],
#  [[154, 194], 0.10526315789473684, ['Nut', 'Roasted']],
#  [[154, 198], 0.10526315789473684, ['Nut', 'Roasted Meat']],
#  [[3, 142], 0.1, ['Almonds', 'Meat']],
#  [[21, 245], 0.1, ['Bitter', 'Wine']],
#  [[28, 142], 0.1, ['Box Tree', 'Meat']],
#  [[29, 245], 0.1, ['Brandy', 'Wine']],
#  [[33, 53], 0.1, ['Burnt', 'Cocoa']],
#  [[41, 53], 0.1, ['Caramel', 'Cocoa']],
#  [[47, 142], 0.1, ['Cereal', 'Meat']],
#  [[51, 154], 0.1, ['Citrus', 'Nut']],
#  [[51, 173], 0.1, ['Citrus', 'Pepper']],
#  [[51, 246], 0.1, ['Citrus', 'Wood']],
#  [[53, 154], 0.1, ['Cocoa', 'Nut']],
#  [[53, 182], 0.1, ['Cocoa', 'Popcorn']],
#  [[53, 193], 0.1, ['Cocoa', 'Roast Beef']],
#  [[53, 194], 0.1, ['Cocoa', 'Roasted']],
#  [[53, 199], 0.1, ['Cocoa', 'Roasted Nut']],
#  [[53, 204], 0.1, ['Cocoa', 'Rum']],
#  [[55, 142], 0.1, ['Coffee', 'Meat']],
#  [[63, 245], 0.1, ['Cotton', 'Wine']],
#  [[81, 245], 0.1, ['Fabric', 'Wine']],
#  [[88, 245], 0.1, ['Fish Oil', 'Wine']],
#  [[90, 168], 0.1, ['Flower', 'Peach']],
#  [[93, 202], 0.1, ['Fresh', 'Rose']],
#  [[109, 245], 0.1, ['Green Fruit', 'Wine']],
#  [[115, 142], 0.1, ['Hazelnut', 'Meat']],
#  [[119, 142], 0.1, ['Hop', 'Meat']],
#  [[126, 202], 0.1, ['Lavender', 'Rose']],
#  [[127, 245], 0.1, ['Leaf', 'Wine']],
#  [[129, 142], 0.1, ['Leek', 'Meat']],
#  [[134, 245], 0.1, ['Lilac', 'Wine']],
#  [[137, 245], 0.1, ['Malt', 'Wine']],
#  [[142, 173], 0.1, ['Meat', 'Pepper']],
#  [[142, 183], 0.1, ['Meat', 'Potato']],
#  [[159, 245], 0.1, ['Orange', 'Wine']],
#  [[209, 245], 0.1, ['Solvent', 'Wine']],
#  [[226, 245], 0.1, ['Tomato', 'Wine']],
#  [[227, 245], 0.1, ['Tomato Leaf', 'Wine']],
#  [[239, 245], 0.1, ['Wax', 'Wine']],
#  [[41, 118], 0.09523809523809523, ['Caramel', 'Honey']],
#  [[48, 219], 0.09375, ['Cheese', 'Sulfur']],
#  [[76, 219], 0.09375, ['Durian', 'Sulfur']],
#  [[200, 219], 0.09375, ['Roasted Onion', 'Sulfur']],
#  [[2, 33], 0.09090909090909091, ['Almond', 'Burnt']],
#  [[2, 41], 0.09090909090909091, ['Almond', 'Caramel']],
#  [[5, 48], 0.09090909090909091, ['Apple', 'Cheese']],
#  [[5, 79], 0.09090909090909091, ['Apple', 'Ester']],
#  [[5, 101], 0.09090909090909091, ['Apple', 'Glue']],
#  [[5, 107], 0.09090909090909091, ['Apple', 'Green Apple']],
#  [[5, 204], 0.09090909090909091, ['Apple', 'Rum']],
#  [[14, 33], 0.09090909090909091, ['Baked Potatoes', 'Burnt']],
#  [[15, 50], 0.09090909090909091, ['Balsamic', 'Cinnamon']],
#  [[15, 55], 0.09090909090909091, ['Balsamic', 'Coffee']],
#  [[15, 100], 0.09090909090909091, ['Balsamic', 'Geranium']],
#  [[15, 218], 0.09090909090909091, ['Balsamic', 'Strawberry']],
#  [[15, 247], 0.09090909090909091, ['Balsamic', 'Yeast']],
#  [[23, 112], 0.09090909090909091, ['Black Currant', 'Greenery']],
#  [[23, 130], 0.09090909090909091, ['Black Currant', 'Lemon']],
#  [[23, 144], 0.09090909090909091, ['Black Currant', 'Melon']],
#  [[23, 166], 0.09090909090909091, ['Black Currant', 'Passion Fruit']],
#  [[23, 183], 0.09090909090909091, ['Black Currant', 'Potato']],
#  [[23, 191], 0.09090909090909091, ['Black Currant', 'Rhubarb']],
#  [[30, 33], 0.09090909090909091, ['Bread', 'Burnt']],
#  [[31, 41], 0.09090909090909091, ['Bread Crust', 'Caramel']],
#  [[33, 52], 0.09090909090909091, ['Burnt', 'Clove']],
#  [[33, 57], 0.09090909090909091, ['Burnt', 'Cooked']],
#  [[33, 64], 0.09090909090909091, ['Burnt', 'Cotton Candy']],
#  [[33, 113], 0.09090909090909091, ['Burnt', 'Harsh']],
#  [[33, 122], 0.09090909090909091, ['Burnt', 'Iron Scorch']],
#  [[33, 149], 0.09090909090909091, ['Burnt', 'Mothball']],
#  [[33, 170], 0.09090909090909091, ['Burnt', 'Peanut Butter']],
#  [[33, 176], 0.09090909090909091, ['Burnt', 'Phenol']],
#  [[33, 194], 0.09090909090909091, ['Burnt', 'Roasted']],
#  [[33, 204], 0.09090909090909091, ['Burnt', 'Rum']],
#  [[33, 220], 0.09090909090909091, ['Burnt', 'Sweat']],
#  [[41, 57], 0.09090909090909091, ['Caramel', 'Cooked']],
#  [[41, 64], 0.09090909090909091, ['Caramel', 'Cotton Candy']],
#  [[41, 115], 0.09090909090909091, ['Caramel', 'Hazelnut']],
#  [[41, 137], 0.09090909090909091, ['Caramel', 'Malt']],
#  [[41, 170], 0.09090909090909091, ['Caramel', 'Peanut Butter']],
#  [[41, 174], 0.09090909090909091, ['Caramel', 'Peppermint']],
#  [[41, 182], 0.09090909090909091, ['Caramel', 'Popcorn']],
#  [[41, 194], 0.09090909090909091, ['Caramel', 'Roasted']],
#  [[41, 199], 0.09090909090909091, ['Caramel', 'Roasted Nut']],
#  [[41, 207], 0.09090909090909091, ['Caramel', 'Sharp']],
#  [[99, 185], 0.09090909090909091, ['Garlic', 'Pungent']],
#  [[157, 185], 0.09090909090909091, ['Oil', 'Pungent']],
#  [[76, 158], 0.08695652173913043, ['Durian', 'Onion']],
#  [[93, 157], 0.08695652173913043, ['Fresh', 'Oil']],
#  [[99, 158], 0.08695652173913043, ['Garlic', 'Onion']],
#  [[142, 158], 0.08695652173913043, ['Meat', 'Onion']],
#  [[151, 157], 0.08695652173913043, ['Mushroom', 'Oil']],
#  [[158, 200], 0.08695652173913043, ['Onion', 'Roasted Onion']],
#  [[158, 228], 0.08695652173913043, ['Onion', 'Tropical Fruit']],
#  [[39, 80], 0.08333333333333333, ['Camphor', 'Eucalyptol']],
#  [[39, 130], 0.08333333333333333, ['Camphor', 'Lemon']],
#  [[39, 149], 0.08333333333333333, ['Camphor', 'Mothball']],
#  [[39, 177], 0.08333333333333333, ['Camphor', 'Pine']],
#  [[39, 237], 0.08333333333333333, ['Camphor', 'Warm']],
#  [[82, 104], 0.08108108108108109, ['Fat', 'Grass']],
#  [[4, 93], 0.07692307692307693, ['Anise', 'Fresh']],
#  [[7, 93], 0.07692307692307693, ['Apple Peel', 'Fresh']],
#  [[7, 168], 0.07692307692307693, ['Apple Peel', 'Peach']],
#  [[31, 36], 0.07692307692307693, ['Bread Crust', 'Butter']],
#  [[33, 36], 0.07692307692307693, ['Burnt', 'Butter']],
#  [[36, 54], 0.07692307692307693, ['Butter', 'Coconut']],
#  [[36, 65], 0.07692307692307693, ['Butter', 'Creamy']],
#  [[36, 85], 0.07692307692307693, ['Butter', 'Fermented']],
#  [[36, 87], 0.07692307692307693, ['Butter', 'Fish']],
#  [[36, 108], 0.07692307692307693, ['Butter', 'Green Bean']],
#  [[36, 111], 0.07692307692307693, ['Butter', 'Green Pepper']],
#  [[36, 137], 0.07692307692307693, ['Butter', 'Malt']],
#  [[36, 147], 0.07692307692307693, ['Butter', 'Mold']],
#  [[36, 164], 0.07692307692307693, ['Butter', 'Oxidized']],
#  [[36, 167], 0.07692307692307693, ['Butter', 'Pastry']],
#  [[36, 218], 0.07692307692307693, ['Butter', 'Strawberry']],
#  [[36, 220], 0.07692307692307693, ['Butter', 'Sweat']],
#  [[36, 242], 0.07692307692307693, ['Butter', 'Wet Earth']],
#  [[36, 247], 0.07692307692307693, ['Butter', 'Yeast']],
#  [[42, 93], 0.07692307692307693, ['Caraway', 'Fresh']],
#  [[54, 168], 0.07692307692307693, ['Coconut', 'Peach']],
#  [[79, 93], 0.07692307692307693, ['Ester', 'Fresh']],
#  [[93, 145], 0.07692307692307693, ['Fresh', 'Mint']],
#  [[93, 159], 0.07692307692307693, ['Fresh', 'Orange']],
#  [[93, 166], 0.07692307692307693, ['Fresh', 'Passion Fruit']],
#  [[93, 173], 0.07692307692307693, ['Fresh', 'Pepper']],
#  [[93, 203], 0.07692307692307693, ['Fresh', 'Rubber']],
#  [[93, 209], 0.07692307692307693, ['Fresh', 'Solvent']],
#  [[93, 213], 0.07692307692307693, ['Fresh', 'Spearmint']],
#  [[100, 168], 0.07692307692307693, ['Geranium', 'Peach']],
#  [[125, 168], 0.07692307692307693, ['Lactone', 'Peach']],
#  [[131, 168], 0.07692307692307693, ['Lemon Peel', 'Peach']],
#  [[144, 168], 0.07692307692307693, ['Melon', 'Peach']],
#  [[166, 168], 0.07692307692307693, ['Passion Fruit', 'Peach']],
#  [[3, 152], 0.07142857142857142, ['Almonds', 'Must']],
#  [[11, 37], 0.07142857142857142, ['Asparagus', 'Cabbage']],
#  [[15, 117], 0.07142857142857142, ['Balsamic', 'Herb']],
#  [[15, 152], 0.07142857142857142, ['Balsamic', 'Must']],
#  [[16, 40], 0.07142857142857142, ['Banana', 'Candy']],
#  [[16, 79], 0.07142857142857142, ['Banana', 'Ester']],
#  [[16, 203], 0.07142857142857142, ['Banana', 'Rubber']],
#  [[16, 245], 0.07142857142857142, ['Banana', 'Wine']],
#  [[33, 152], 0.07142857142857142, ['Burnt', 'Must']],
#  [[36, 117], 0.07142857142857142, ['Butter', 'Herb']],
#  [[37, 43], 0.07142857142857142, ['Cabbage', 'Carbide']],
#  [[37, 87], 0.07142857142857142, ['Cabbage', 'Fish']],
#  [[37, 151], 0.07142857142857142, ['Cabbage', 'Mushroom']],
#  [[37, 152], 0.07142857142857142, ['Cabbage', 'Must']],
#  [[37, 161], 0.07142857142857142, ['Cabbage', 'Organic']],
#  [[37, 183], 0.07142857142857142, ['Cabbage', 'Potato']],
#  [[37, 188], 0.07142857142857142, ['Cabbage', 'Radish']],
#  [[37, 200], 0.07142857142857142, ['Cabbage', 'Roasted Onion']],
#  [[37, 203], 0.07142857142857142, ['Cabbage', 'Rubber']],
#  [[37, 228], 0.07142857142857142, ['Cabbage', 'Tropical Fruit']],
#  [[37, 242], 0.07142857142857142, ['Cabbage', 'Wet Earth']],
#  [[58, 99], 0.07142857142857142, ['Cooked Meat', 'Garlic']],
#  [[60, 99], 0.07142857142857142, ['Cooked potato', 'Garlic']],
#  [[90, 117], 0.07142857142857142, ['Flower', 'Herb']],
#  [[99, 183], 0.07142857142857142, ['Garlic', 'Potato']],
#  [[99, 188], 0.07142857142857142, ['Garlic', 'Radish']],
#  [[99, 199], 0.07142857142857142, ['Garlic', 'Roasted Nut']],
#  [[99, 212], 0.07142857142857142, ['Garlic', 'Soy']],
#  [[99, 228], 0.07142857142857142, ['Garlic', 'Tropical Fruit']],
#  [[100, 152], 0.07142857142857142, ['Geranium', 'Must']],
#  [[117, 152], 0.07142857142857142, ['Herb', 'Must']],
#  [[117, 246], 0.07142857142857142, ['Herb', 'Wood']],
#  [[122, 152], 0.07142857142857142, ['Iron Scorch', 'Must']],
#  [[142, 152], 0.07142857142857142, ['Meat', 'Must']],
#  [[152, 155], 0.07142857142857142, ['Must', 'Nutmeg']],
#  [[152, 170], 0.07142857142857142, ['Must', 'Peanut Butter']],
#  [[152, 204], 0.07142857142857142, ['Must', 'Rum']],
#  [[19, 78], 0.06666666666666667, ['Bell Pepper', 'Earth']],
#  [[67, 78], 0.06666666666666667, ['Cucumber', 'Earth']],
#  [[78, 94], 0.06666666666666667, ['Earth', 'Fried']],
#  [[78, 99], 0.06666666666666667, ['Earth', 'Garlic']],
#  [[78, 111], 0.06666666666666667, ['Earth', 'Green Pepper']],
#  [[78, 142], 0.06666666666666667, ['Earth', 'Meat']],
#  [[78, 148], 0.06666666666666667, ['Earth', 'Moss']],
#  [[78, 155], 0.06666666666666667, ['Earth', 'Nutmeg']],
#  [[78, 177], 0.06666666666666667, ['Earth', 'Pine']],
#  [[78, 203], 0.06666666666666667, ['Earth', 'Rubber']],
#  [[78, 212], 0.06666666666666667, ['Earth', 'Soy']],
#  [[23, 219], 0.0625, ['Black Currant', 'Sulfur']],
#  [[78, 219], 0.0625, ['Earth', 'Sulfur']],
#  [[142, 219], 0.0625, ['Meat', 'Sulfur']],
#  [[188, 219], 0.0625, ['Radish', 'Sulfur']],
#  [[192, 219], 0.0625, ['Roast', 'Sulfur']],
#  [[203, 219], 0.0625, ['Rubber', 'Sulfur']],
#  [[219, 228], 0.0625, ['Sulfur', 'Tropical Fruit']],
#  [[2, 185], 0.06060606060606061, ['Almond', 'Pungent']],
#  [[16, 185], 0.06060606060606061, ['Banana', 'Pungent']],
#  [[137, 185], 0.06060606060606061, ['Malt', 'Pungent']],
#  [[158, 185], 0.06060606060606061, ['Onion', 'Pungent']],
#  [[7, 178], 0.058823529411764705, ['Apple Peel', 'Pineapple']],
#  [[16, 48], 0.058823529411764705, ['Banana', 'Cheese']],
#  [[16, 178], 0.058823529411764705, ['Banana', 'Pineapple']],
#  [[20, 178], 0.058823529411764705, ['Berry', 'Pineapple']],
#  [[27, 246], 0.058823529411764705, ['Boiled Vegetable', 'Wood']],
#  [[36, 178], 0.058823529411764705, ['Butter', 'Pineapple']],
#  [[41, 48], 0.058823529411764705, ['Caramel', 'Cheese']],
#  [[48, 79], 0.058823529411764705, ['Cheese', 'Ester']],
#  [[48, 85], 0.058823529411764705, ['Cheese', 'Fermented']],
#  [[48, 104], 0.058823529411764705, ['Cheese', 'Grass']],
#  [[48, 113], 0.058823529411764705, ['Cheese', 'Harsh']],
#  [[48, 115], 0.058823529411764705, ['Cheese', 'Hazelnut']],
#  [[48, 142], 0.058823529411764705, ['Cheese', 'Meat']],
#  [[48, 151], 0.058823529411764705, ['Cheese', 'Mushroom']],
#  [[48, 178], 0.058823529411764705, ['Cheese', 'Pineapple']],
#  [[48, 199], 0.058823529411764705, ['Cheese', 'Roasted Nut']],
#  [[48, 203], 0.058823529411764705, ['Cheese', 'Rubber']],
#  [[48, 216], 0.058823529411764705, ['Cheese', 'Stinging Nettle']],
#  [[48, 218], 0.058823529411764705, ['Cheese', 'Strawberry']],
#  [[48, 220], 0.058823529411764705, ['Cheese', 'Sweat']],
#  [[79, 178], 0.058823529411764705, ['Ester', 'Pineapple']],
#  [[93, 178], 0.058823529411764705, ['Fresh', 'Pineapple']],
#  [[93, 246], 0.058823529411764705, ['Fresh', 'Wood']],
#  [[94, 246], 0.058823529411764705, ['Fried', 'Wood']],
#  [[96, 178], 0.058823529411764705, ['Fruit Gum', 'Pineapple']],
#  [[122, 246], 0.058823529411764705, ['Iron Scorch', 'Wood']],
#  [[147, 246], 0.058823529411764705, ['Mold', 'Wood']],
#  [[148, 246], 0.058823529411764705, ['Moss', 'Wood']],
#  [[155, 246], 0.058823529411764705, ['Nutmeg', 'Wood']],
#  [[163, 178], 0.058823529411764705, ['Overripe Fruit', 'Pineapple']],
#  [[170, 246], 0.058823529411764705, ['Peanut Butter', 'Wood']],
#  [[173, 246], 0.058823529411764705, ['Pepper', 'Wood']],
#  [[175, 178], 0.058823529411764705, ['Petrol', 'Pineapple']],
#  [[176, 246], 0.058823529411764705, ['Phenol', 'Wood']],
#  [[177, 246], 0.058823529411764705, ['Pine', 'Wood']],
#  [[178, 197], 0.058823529411764705, ['Pineapple', 'Roasted Garlic']],
#  [[178, 204], 0.058823529411764705, ['Pineapple', 'Rum']],
#  [[178, 209], 0.058823529411764705, ['Pineapple', 'Solvent']],
#  [[178, 211], 0.058823529411764705, ['Pineapple', 'Sour']],
#  [[181, 246], 0.058823529411764705, ['Polish', 'Wood']],
#  [[194, 246], 0.058823529411764705, ['Roasted', 'Wood']],
#  [[204, 246], 0.058823529411764705, ['Rum', 'Wood']],
#  [[235, 246], 0.058823529411764705, ['Violet', 'Wood']],
#  [[13, 192], 0.05555555555555555, ['Baked', 'Roast']],
#  [[23, 192], 0.05555555555555555, ['Black Currant', 'Roast']],
#  [[41, 192], 0.05555555555555555, ['Caramel', 'Roast']],
#  [[44, 192], 0.05555555555555555, ['Cat', 'Roast']],
#  [[55, 192], 0.05555555555555555, ['Coffee', 'Roast']],
#  [[146, 192], 0.05555555555555555, ['Mocha', 'Roast']],
#  [[152, 192], 0.05555555555555555, ['Must', 'Roast']],
#  [[169, 192], 0.05555555555555555, ['Peanut', 'Roast']],
#  [[192, 194], 0.05555555555555555, ['Roast', 'Roasted']],
#  [[192, 196], 0.05555555555555555, ['Roast', 'Roasted Corn']],
#  [[192, 224], 0.05555555555555555, ['Roast', 'Toasted Cereal']],
#  [[67, 82], 0.05405405405405406, ['Cucumber', 'Fat']],
#  [[72, 82], 0.05405405405405406, ['Deep Fried', 'Fat']],
#  [[82, 93], 0.05405405405405406, ['Fat', 'Fresh']],
#  [[82, 151], 0.05405405405405406, ['Fat', 'Mushroom']],
#  [[82, 154], 0.05405405405405406, ['Fat', 'Nut']],
#  [[82, 211], 0.05405405405405406, ['Fat', 'Sour']],
#  [[214, 246], 0.05333333333333334, ['Spice', 'Wood']],
#  [[20, 154], 0.05263157894736842, ['Berry', 'Nut']],
#  [[24, 154], 0.05263157894736842, ['Blue Cheese', 'Nut']],
#  [[47, 154], 0.05263157894736842, ['Cereal', 'Nut']],
#  [[58, 154], 0.05263157894736842, ['Cooked Meat', 'Nut']],
#  [[74, 154], 0.05263157894736842, ['Dry Fish', 'Nut']],
#  [[75, 154], 0.05263157894736842, ['Dull', 'Nut']],
#  [[94, 154], 0.05263157894736842, ['Fried', 'Nut']],
#  [[100, 154], 0.05263157894736842, ['Geranium', 'Nut']],
#  [[115, 154], 0.05263157894736842, ['Hazelnut', 'Nut']],
#  [[142, 154], 0.05263157894736842, ['Meat', 'Nut']],
#  [[148, 154], 0.05263157894736842, ['Moss', 'Nut']],
#  [[151, 154], 0.05263157894736842, ['Mushroom', 'Nut']],
#  [[152, 154], 0.05263157894736842, ['Must', 'Nut']],
#  [[154, 203], 0.05263157894736842, ['Nut', 'Rubber']],
#  [[154, 222], 0.05263157894736842, ['Nut', 'Thiamin']],
#  [[154, 233], 0.05263157894736842, ['Nut', 'Vegetable']],
#  [[154, 247], 0.05263157894736842, ['Nut', 'Yeast']],
#  [[2, 53], 0.05, ['Almond', 'Cocoa']],
#  [[3, 90], 0.05, ['Almonds', 'Flower']],
#  [[6, 202], 0.05, ['Apple ', 'Rose']],
#  [[7, 51], 0.05, ['Apple Peel', 'Citrus']],
#  [[8, 90], 0.05, ['Apricot', 'Flower']],
#  [[13, 53], 0.05, ['Baked', 'Cocoa']],
#  [[15, 53], 0.05, ['Balsamic', 'Cocoa']],
#  [[16, 90], 0.05, ['Banana', 'Flower']],
#  [[21, 51], 0.05, ['Bitter', 'Citrus']],
#  [[21, 53], 0.05, ['Bitter', 'Cocoa']],
#  [[23, 51], 0.05, ['Black Currant', 'Citrus']],
#  [[23, 90], 0.05, ['Black Currant', 'Flower']],
#  [[26, 202], 0.05, ['Boiled Cherries', 'Rose']],
#  [[28, 51], 0.05, ['Box Tree', 'Citrus']],
#  [[30, 53], 0.05, ['Bread', 'Cocoa']],
#  [[36, 53], 0.05, ['Butter', 'Cocoa']],
#  [[38, 90], 0.05, ['Camomile', 'Flower']],
#  [[41, 90], 0.05, ['Caramel', 'Flower']],
#  [[44, 51], 0.05, ['Cat', 'Citrus']],
#  [[44, 90], 0.05, ['Cat', 'Flower']],
#  [[46, 90], 0.05, ['Celery', 'Flower']],
#  [[51, 62], 0.05, ['Citrus', 'Coriander']],
#  [[51, 78], 0.05, ['Citrus', 'Earth']],
#  [[51, 94], 0.05, ['Citrus', 'Fried']],
#  [[51, 127], 0.05, ['Citrus', 'Leaf']],
#  [[51, 135], 0.05, ['Citrus', 'Lily']],
#  [[51, 142], 0.05, ['Citrus', 'Meat']],
#  [[51, 148], 0.05, ['Citrus', 'Moss']],
#  [[51, 177], 0.05, ['Citrus', 'Pine']],
#  [[51, 189], 0.05, ['Citrus', 'Raspberry']],
#  [[51, 202], 0.05, ['Citrus', 'Rose']],
#  [[51, 203], 0.05, ['Citrus', 'Rubber']],
#  [[51, 209], 0.05, ['Citrus', 'Solvent']],
#  [[51, 218], 0.05, ['Citrus', 'Strawberry']],
#  [[53, 54], 0.05, ['Cocoa', 'Coconut']],
#  [[53, 78], 0.05, ['Cocoa', 'Earth']],
#  [[53, 85], 0.05, ['Cocoa', 'Fermented']],
#  [[53, 133], 0.05, ['Cocoa', 'Licorice']],
#  [[53, 146], 0.05, ['Cocoa', 'Mocha']],
#  [[53, 152], 0.05, ['Cocoa', 'Must']],
#  [[53, 170], 0.05, ['Cocoa', 'Peanut Butter']],
#  [[53, 183], 0.05, ['Cocoa', 'Potato']],
#  [[53, 236], 0.05, ['Cocoa', 'Walnut']],
#  [[53, 245], 0.05, ['Cocoa', 'Wine']],
#  [[62, 202], 0.05, ['Coriander', 'Rose']],
#  [[75, 202], 0.05, ['Dull', 'Rose']],
#  [[77, 202], 0.05, ['Dust', 'Rose']],
#  [[90, 92], 0.05, ['Flower', 'Fragrant']],
#  [[90, 103], 0.05, ['Flower', 'Grapefruit']],
#  [[90, 104], 0.05, ['Flower', 'Grass']],
#  [[90, 130], 0.05, ['Flower', 'Lemon']],
#  [[90, 142], 0.05, ['Flower', 'Meat']],
#  [[90, 152], 0.05, ['Flower', 'Must']],
#  [[90, 202], 0.05, ['Flower', 'Rose']],
#  [[90, 236], 0.05, ['Flower', 'Walnut']],
#  [[90, 237], 0.05, ['Flower', 'Warm']],
#  [[90, 239], 0.05, ['Flower', 'Wax']],
#  [[92, 202], 0.05, ['Fragrant', 'Rose']],
#  [[100, 202], 0.05, ['Geranium', 'Rose']],
#  [[130, 202], 0.05, ['Lemon', 'Rose']],
#  [[131, 202], 0.05, ['Lemon Peel', 'Rose']],
#  [[134, 202], 0.05, ['Lilac', 'Rose']],
#  [[148, 202], 0.05, ['Moss', 'Rose']],
#  [[154, 202], 0.05, ['Nut', 'Rose']],
#  [[159, 202], 0.05, ['Orange', 'Rose']],
#  [[166, 202], 0.05, ['Passion Fruit', 'Rose']],
#  [[168, 202], 0.05, ['Peach', 'Rose']],
#  [[195, 202], 0.05, ['Roasted Bread', 'Rose']],
#  [[202, 237], 0.05, ['Rose', 'Warm']],
#  [[202, 245], 0.05, ['Rose', 'Wine']],
#  [[82, 106], 0.04926108374384237, ['Fat', 'Green']],
#  [[15, 118], 0.047619047619047616, ['Balsamic', 'Honey']],
#  [[20, 118], 0.047619047619047616, ['Berry', 'Honey']],
#  [[33, 118], 0.047619047619047616, ['Burnt', 'Honey']],
#  [[50, 118], 0.047619047619047616, ['Cinnamon', 'Honey']],
#  [[64, 118], 0.047619047619047616, ['Cotton Candy', 'Honey']],
#  [[68, 118], 0.047619047619047616, ['Curry', 'Honey']],
#  [[100, 118], 0.047619047619047616, ['Geranium', 'Honey']],
#  [[118, 123], 0.047619047619047616, ['Honey', 'Jasmine']],
#  [[118, 134], 0.047619047619047616, ['Honey', 'Lilac']],
#  [[118, 154], 0.047619047619047616, ['Honey', 'Nut']],
#  [[118, 168], 0.047619047619047616, ['Honey', 'Peach']],
#  [[118, 237], 0.047619047619047616, ['Honey', 'Warm']],
#  [[118, 245], 0.047619047619047616, ['Honey', 'Wine']],
#  [[118, 246], 0.047619047619047616, ['Honey', 'Wood']],
#  [[5, 8], 0.045454545454545456, ['Apple', 'Apricot']],
#  [[5, 20], 0.045454545454545456, ['Apple', 'Berry']],
#  [[5, 21], 0.045454545454545456, ['Apple', 'Bitter']],
#  [[5, 36], 0.045454545454545456, ['Apple', 'Butter']],
#  [[5, 51], 0.045454545454545456, ['Apple', 'Citrus']],
#  [[5, 53], 0.045454545454545456, ['Apple', 'Cocoa']],
#  [[5, 74], 0.045454545454545456, ['Apple', 'Dry Fish']],
#  [[5, 93], 0.045454545454545456, ['Apple', 'Fresh']],
#  [[5, 104], 0.045454545454545456, ['Apple', 'Grass']],
#  [[5, 124], 0.045454545454545456, ['Apple', 'Kiwi']],
#  [[5, 154], 0.045454545454545456, ['Apple', 'Nut']],
#  [[5, 202], 0.045454545454545456, ['Apple', 'Rose']],
#  [[5, 211], 0.045454545454545456, ['Apple', 'Sour']],
#  [[5, 245], 0.045454545454545456, ['Apple', 'Wine']],
#  [[5, 247], 0.045454545454545456, ['Apple', 'Yeast']],
#  [[2, 157], 0.043478260869565216, ['Almond', 'Oil']],
#  [[4, 157], 0.043478260869565216, ['Anise', 'Oil']],
#  [[5, 157], 0.043478260869565216, ['Apple', 'Oil']],
#  [[15, 157], 0.043478260869565216, ['Balsamic', 'Oil']],
#  [[21, 157], 0.043478260869565216, ['Bitter', 'Oil']],
#  [[23, 158], 0.043478260869565216, ['Black Currant', 'Onion']],
#  [[33, 157], 0.043478260869565216, ['Burnt', 'Oil']],
#  [[39, 157], 0.043478260869565216, ['Camphor', 'Oil']],
#  [[40, 158], 0.043478260869565216, ['Candy', 'Onion']],
#  [[44, 158], 0.043478260869565216, ['Cat', 'Onion']],
#  [[48, 158], 0.043478260869565216, ['Cheese', 'Onion']],
#  [[58, 158], 0.043478260869565216, ['Cooked Meat', 'Onion']],
#  [[59, 157], 0.043478260869565216, ['Cooked Nut', 'Oil']],
#  [[62, 157], 0.043478260869565216, ['Coriander', 'Oil']],
#  [[72, 157], 0.043478260869565216, ['Deep Fried', 'Oil']],
#  [[78, 157], 0.043478260869565216, ['Earth', 'Oil']],
#  [[78, 158], 0.043478260869565216, ['Earth', 'Onion']],
#  [[87, 158], 0.043478260869565216, ['Fish', 'Onion']],
#  [[88, 158], 0.043478260869565216, ['Fish Oil', 'Onion']],
#  [[90, 157], 0.043478260869565216, ['Flower', 'Oil']],
#  [[94, 157], 0.043478260869565216, ['Fried', 'Oil']],
#  [[104, 157], 0.043478260869565216, ['Grass', 'Oil']],
#  [[105, 158], 0.043478260869565216, ['Gravy', 'Onion']],
#  [[113, 157], 0.043478260869565216, ['Harsh', 'Oil']],
#  [[115, 158], 0.043478260869565216, ['Hazelnut', 'Onion']],
#  [[118, 157], 0.043478260869565216, ['Honey', 'Oil']],
#  [[119, 158], 0.043478260869565216, ['Hop', 'Onion']],
#  [[137, 157], 0.043478260869565216, ['Malt', 'Oil']],
#  [[137, 158], 0.043478260869565216, ['Malt', 'Onion']],
#  [[148, 157], 0.043478260869565216, ['Moss', 'Oil']],
#  [[149, 157], 0.043478260869565216, ['Mothball', 'Oil']],
#  [[152, 158], 0.043478260869565216, ['Must', 'Onion']],
#  [[154, 157], 0.043478260869565216, ['Nut', 'Oil']],
#  [[157, 159], 0.043478260869565216, ['Oil', 'Orange']],
#  [[157, 164], 0.043478260869565216, ['Oil', 'Oxidized']],
#  [[157, 211], 0.043478260869565216, ['Oil', 'Sour']],
#  [[157, 237], 0.043478260869565216, ['Oil', 'Warm']],
#  [[157, 246], 0.043478260869565216, ['Oil', 'Wood']],
#  [[158, 172], 0.043478260869565216, ['Onion', 'Penetrating']],
#  [[158, 173], 0.043478260869565216, ['Onion', 'Pepper']],
#  [[158, 188], 0.043478260869565216, ['Onion', 'Radish']],
#  [[158, 194], 0.043478260869565216, ['Onion', 'Roasted']],
#  [[158, 203], 0.043478260869565216, ['Onion', 'Rubber']],
#  [[158, 210], 0.043478260869565216, ['Onion', 'Soup']],
#  [[158, 216], 0.043478260869565216, ['Onion', 'Stinging Nettle']],
#  [[158, 245], 0.043478260869565216, ['Onion', 'Wine']],
#  [[2, 214], 0.04, ['Almond', 'Spice']],
#  [[52, 214], 0.04, ['Clove', 'Spice']],
#  [[68, 214], 0.04, ['Curry', 'Spice']],
#  [[176, 214], 0.04, ['Phenol', 'Spice']],
#  [[106, 185], 0.03940886699507389, ['Green', 'Pungent']],
#  [[4, 145], 0.038461538461538464, ['Anise', 'Mint']],
#  [[17, 145], 0.038461538461538464, ['Basil', 'Mint']],
#  [[21, 145], 0.038461538461538464, ['Bitter', 'Mint']],
#  [[39, 145], 0.038461538461538464, ['Camphor', 'Mint']],
#  [[42, 145], 0.038461538461538464, ['Caraway', 'Mint']],
#  [[51, 145], 0.038461538461538464, ['Citrus', 'Mint']],
#  [[84, 145], 0.038461538461538464, ['Fennel', 'Mint']],
#  [[0, 117], 0.03571428571428571, ['Acid', 'Herb']],
#  [[11, 117], 0.03571428571428571, ['Asparagus', 'Herb']],
#  [[37, 117], 0.03571428571428571, ['Cabbage', 'Herb']],
#  [[51, 117], 0.03571428571428571, ['Citrus', 'Herb']],
#  [[59, 117], 0.03571428571428571, ['Cooked Nut', 'Herb']],
#  [[74, 117], 0.03571428571428571, ['Dry Fish', 'Herb']],
#  [[100, 117], 0.03571428571428571, ['Geranium', 'Herb']],
#  [[109, 117], 0.03571428571428571, ['Green Fruit', 'Herb']],
#  [[110, 117], 0.03571428571428571, ['Green Leaf', 'Herb']],
#  [[117, 118], 0.03571428571428571, ['Herb', 'Honey']],
#  [[117, 132], 0.03571428571428571, ['Herb', 'Lettuce']],
#  [[117, 137], 0.03571428571428571, ['Herb', 'Malt']],
#  [[117, 147], 0.03571428571428571, ['Herb', 'Mold']],
#  [[117, 151], 0.03571428571428571, ['Herb', 'Mushroom']],
#  [[117, 154], 0.03571428571428571, ['Herb', 'Nut']],
#  [[117, 171], 0.03571428571428571, ['Herb', 'Pear']],
#  [[117, 177], 0.03571428571428571, ['Herb', 'Pine']],
#  [[117, 183], 0.03571428571428571, ['Herb', 'Potato']],
#  [[117, 184], 0.03571428571428571, ['Herb', 'Prune']],
#  [[117, 202], 0.03571428571428571, ['Herb', 'Rose']],
#  [[117, 207], 0.03571428571428571, ['Herb', 'Sharp']],
#  [[117, 229], 0.03571428571428571, ['Herb', 'Truffle']],
#  [[117, 231], 0.03571428571428571, ['Herb', 'Unripe Banana']],
#  [[117, 235], 0.03571428571428571, ['Herb', 'Violet']],
#  [[117, 237], 0.03571428571428571, ['Herb', 'Warm']],
#  [[117, 239], 0.03571428571428571, ['Herb', 'Wax']],
#  [[117, 247], 0.03571428571428571, ['Herb', 'Yeast']],
#  [[39, 106], 0.034482758620689655, ['Camphor', 'Green']],
#  [[89, 95], 0.03153153153153153, ['Floral', 'Fruit']],
#  [[39, 219], 0.03125, ['Camphor', 'Sulfur']],
#  [[43, 219], 0.03125, ['Carbide', 'Sulfur']],
#  [[44, 219], 0.03125, ['Cat', 'Sulfur']],
#  [[55, 219], 0.03125, ['Coffee', 'Sulfur']],
#  [[58, 219], 0.03125, ['Cooked Meat', 'Sulfur']],
#  [[87, 219], 0.03125, ['Fish', 'Sulfur']],
#  [[103, 219], 0.03125, ['Grapefruit', 'Sulfur']],
#  [[129, 219], 0.03125, ['Leek', 'Sulfur']],
#  [[139, 219], 0.03125, ['Mango', 'Sulfur']],
#  [[151, 219], 0.03125, ['Mushroom', 'Sulfur']],
#  [[154, 219], 0.03125, ['Nut', 'Sulfur']],
#  [[161, 219], 0.03125, ['Organic', 'Sulfur']],
#  [[172, 219], 0.03125, ['Penetrating', 'Sulfur']],
#  [[182, 219], 0.03125, ['Popcorn', 'Sulfur']],
#  [[191, 219], 0.03125, ['Rhubarb', 'Sulfur']],
#  [[219, 242], 0.03125, ['Sulfur', 'Wet Earth']],
#  [[0, 185], 0.030303030303030304, ['Acid', 'Pungent']],
#  [[1, 185], 0.030303030303030304, ['Alcohol', 'Pungent']],
#  [[5, 185], 0.030303030303030304, ['Apple', 'Pungent']],
#  [[15, 185], 0.030303030303030304, ['Balsamic', 'Pungent']],
#  [[20, 185], 0.030303030303030304, ['Berry', 'Pungent']],
#  [[21, 185], 0.030303030303030304, ['Bitter', 'Pungent']],
#  [[36, 185], 0.030303030303030304, ['Butter', 'Pungent']],
#  [[37, 185], 0.030303030303030304, ['Cabbage', 'Pungent']],
#  [[40, 185], 0.030303030303030304, ['Candy', 'Pungent']],
#  [[49, 185], 0.030303030303030304, ['Cherry', 'Pungent']],
#  [[51, 185], 0.030303030303030304, ['Citrus', 'Pungent']],
#  [[58, 185], 0.030303030303030304, ['Cooked Meat', 'Pungent']],
#  [[65, 185], 0.030303030303030304, ['Creamy', 'Pungent']],
#  [[87, 185], 0.030303030303030304, ['Fish', 'Pungent']],
#  [[100, 185], 0.030303030303030304, ['Geranium', 'Pungent']],
#  [[101, 185], 0.030303030303030304, ['Glue', 'Pungent']],
#  [[115, 185], 0.030303030303030304, ['Hazelnut', 'Pungent']],
#  [[117, 185], 0.030303030303030304, ['Herb', 'Pungent']],
#  [[118, 185], 0.030303030303030304, ['Honey', 'Pungent']],
#  [[153, 185], 0.030303030303030304, ['Mustard', 'Pungent']],
#  [[154, 185], 0.030303030303030304, ['Nut', 'Pungent']],
#  [[156, 169], 0.030303030303030304, ['Nuts', 'Peanut']],
#  [[156, 192], 0.030303030303030304, ['Nuts', 'Roast']],
#  [[156, 194], 0.030303030303030304, ['Nuts', 'Roasted']],
#  [[156, 219], 0.030303030303030304, ['Nuts', 'Sulfur']],
#  [[176, 185], 0.030303030303030304, ['Phenol', 'Pungent']],
#  [[185, 203], 0.030303030303030304, ['Pungent', 'Rubber']],
#  [[185, 208], 0.030303030303030304, ['Pungent', 'Silage']],
#  [[185, 209], 0.030303030303030304, ['Pungent', 'Solvent']],
#  [[185, 212], 0.030303030303030304, ['Pungent', 'Soy']],
#  [[185, 215], 0.030303030303030304, ['Pungent', 'Stable']],
#  [[185, 216], 0.030303030303030304, ['Pungent', 'Stinging Nettle']],
#  [[185, 234], 0.030303030303030304, ['Pungent', 'Vinegar']],
#  [[185, 247], 0.030303030303030304, ['Pungent', 'Yeast']],
#  [[106, 154], 0.029556650246305417, ['Green', 'Nut']],
#  [[106, 194], 0.029556650246305417, ['Green', 'Roasted']],
#  [[2, 82], 0.02702702702702703, ['Almond', 'Fat']],
#  [[5, 82], 0.02702702702702703, ['Apple', 'Fat']],
#  [[8, 82], 0.02702702702702703, ['Apricot', 'Fat']],
#  [[22, 82], 0.02702702702702703, ['Bitter Almond', 'Fat']],
#  [[29, 82], 0.02702702702702703, ['Brandy', 'Fat']],
#  [[34, 82], 0.02702702702702703, ['Burnt Matches', 'Fat']],
#  [[38, 82], 0.02702702702702703, ['Camomile', 'Fat']],
#  [[42, 82], 0.02702702702702703, ['Caraway', 'Fat']],
#  [[46, 82], 0.02702702702702703, ['Celery', 'Fat']],
#  [[47, 82], 0.02702702702702703, ['Cereal', 'Fat']],
#  [[48, 82], 0.02702702702702703, ['Cheese', 'Fat']],
#  [[49, 82], 0.02702702702702703, ['Cherry', 'Fat']],
#  [[53, 82], 0.02702702702702703, ['Cocoa', 'Fat']],
#  [[58, 82], 0.02702702702702703, ['Cooked Meat', 'Fat']],
#  [[62, 82], 0.02702702702702703, ['Coriander', 'Fat']],
#  [[71, 82], 0.02702702702702703, ['Dandelion', 'Fat']],
#  [[76, 82], 0.02702702702702703, ['Durian', 'Fat']],
#  [[77, 82], 0.02702702702702703, ['Dust', 'Fat']],
#  [[78, 82], 0.02702702702702703, ['Earth', 'Fat']],
#  [[82, 87], 0.02702702702702703, ['Fat', 'Fish']],
#  [[82, 90], 0.02702702702702703, ['Fat', 'Flower']],
#  [[82, 92], 0.02702702702702703, ['Fat', 'Fragrant']],
#  [[82, 125], 0.02702702702702703, ['Fat', 'Lactone']],
#  [[82, 127], 0.02702702702702703, ['Fat', 'Leaf']],
#  [[82, 130], 0.02702702702702703, ['Fat', 'Lemon']],
#  [[82, 135], 0.02702702702702703, ['Fat', 'Lily']],
#  [[82, 139], 0.02702702702702703, ['Fat', 'Mango']],
#  [[82, 143], 0.02702702702702703, ['Fat', 'Meat Broth']],
#  [[82, 147], 0.02702702702702703, ['Fat', 'Mold']],
#  [[82, 152], 0.02702702702702703, ['Fat', 'Must']],
#  [[82, 159], 0.02702702702702703, ['Fat', 'Orange']],
#  [[82, 162], 0.02702702702702703, ['Fat', 'Orris']],
#  [[82, 164], 0.02702702702702703, ['Fat', 'Oxidized']],
#  [[82, 168], 0.02702702702702703, ['Fat', 'Peach']],
#  [[82, 178], 0.02702702702702703, ['Fat', 'Pineapple']],
#  [[82, 182], 0.02702702702702703, ['Fat', 'Popcorn']],
#  [[82, 192], 0.02702702702702703, ['Fat', 'Roast']],
#  [[82, 206], 0.02702702702702703, ['Fat', 'Seaweed']],
#  [[82, 208], 0.02702702702702703, ['Fat', 'Silage']],
#  [[82, 212], 0.02702702702702703, ['Fat', 'Soy']],
#  [[82, 213], 0.02702702702702703, ['Fat', 'Spearmint']],
#  [[82, 221], 0.02702702702702703, ['Fat', 'Tallow']],
#  [[82, 238], 0.02702702702702703, ['Fat', 'Watermelon']],
#  [[82, 244], 0.02702702702702703, ['Fat', 'Wet Wool']],
#  [[33, 214], 0.02666666666666667, ['Burnt', 'Spice']],
#  [[78, 214], 0.02666666666666667, ['Earth', 'Spice']],
#  [[82, 214], 0.02666666666666667, ['Fat', 'Spice']],
#  [[185, 214], 0.02666666666666667, ['Pungent', 'Spice']],
#  [[89, 118], 0.026217228464419477, ['Floral', 'Honey']],
#  [[95, 106], 0.024774774774774775, ['Fruit', 'Green']],
#  [[53, 106], 0.024630541871921183, ['Cocoa', 'Green']],
#  [[106, 157], 0.024630541871921183, ['Green', 'Oil']],
#  [[39, 61], 0.023255813953488372, ['Camphor', 'Cool']],
#  [[61, 80], 0.023255813953488372, ['Cool', 'Eucalyptol']],
#  [[61, 93], 0.023255813953488372, ['Cool', 'Fresh']],
#  [[89, 106], 0.02247191011235955, ['Floral', 'Green']],
#  [[205, 230], 0.0205761316872428, ['Savory', 'Umami']],
#  [[51, 106], 0.019704433497536946, ['Citrus', 'Green']],
#  [[106, 152], 0.019704433497536946, ['Green', 'Must']],
#  [[106, 158], 0.019704433497536946, ['Green', 'Onion']],
#  [[106, 202], 0.019704433497536946, ['Green', 'Rose']],
#  [[106, 214], 0.019704433497536946, ['Green', 'Spice']],
#  [[2, 145], 0.019230769230769232, ['Almond', 'Mint']],
#  [[80, 145], 0.019230769230769232, ['Eucalyptol', 'Mint']],
#  [[145, 145], 0.019230769230769232, ['Mint', 'Mint']],
#  [[145, 157], 0.019230769230769232, ['Mint', 'Oil']],
#  [[145, 173], 0.019230769230769232, ['Mint', 'Pepper']],
#  [[145, 207], 0.019230769230769232, ['Mint', 'Sharp']],
#  [[145, 246], 0.019230769230769232, ['Mint', 'Wood']],
#  [[82, 89], 0.018726591760299626, ['Fat', 'Floral']],
#  [[89, 202], 0.018726591760299626, ['Floral', 'Rose']],
#  [[95, 178], 0.018018018018018018, ['Fruit', 'Pineapple']],
#  [[82, 95], 0.015765765765765764, ['Fat', 'Fruit']],
#  [[95, 202], 0.015765765765765764, ['Fruit', 'Rose']],
#  [[89, 185], 0.0149812734082397, ['Floral', 'Pungent']],
#  [[16, 106], 0.014778325123152709, ['Banana', 'Green']],
#  [[78, 106], 0.014778325123152709, ['Earth', 'Green']],
#  [[92, 106], 0.014778325123152709, ['Fragrant', 'Green']],
#  [[93, 106], 0.014778325123152709, ['Fresh', 'Green']],
#  [[104, 106], 0.014778325123152709, ['Grass', 'Green']],
#  [[106, 117], 0.014778325123152709, ['Green', 'Herb']],
#  [[106, 192], 0.014778325123152709, ['Green', 'Roast']],
#  [[106, 219], 0.014778325123152709, ['Green', 'Sulfur']],
#  [[106, 245], 0.014778325123152709, ['Green', 'Wine']],
#  [[106, 246], 0.014778325123152709, ['Green', 'Wood']],
#  [[95, 185], 0.013513513513513514, ['Fruit', 'Pungent']],
#  [[4, 214], 0.013333333333333334, ['Anise', 'Spice']],
#  [[14, 214], 0.013333333333333334, ['Baked Potatoes', 'Spice']],
#  [[19, 214], 0.013333333333333334, ['Bell Pepper', 'Spice']],
#  [[22, 214], 0.013333333333333334, ['Bitter Almond', 'Spice']],
#  [[24, 214], 0.013333333333333334, ['Blue Cheese', 'Spice']],
#  [[30, 214], 0.013333333333333334, ['Bread', 'Spice']],
#  [[37, 214], 0.013333333333333334, ['Cabbage', 'Spice']],
#  [[39, 214], 0.013333333333333334, ['Camphor', 'Spice']],
#  [[42, 214], 0.013333333333333334, ['Caraway', 'Spice']],
#  [[45, 214], 0.013333333333333334, ['Cedarwood', 'Spice']],
#  [[49, 214], 0.013333333333333334, ['Cherry', 'Spice']],
#  [[51, 214], 0.013333333333333334, ['Citrus', 'Spice']],
#  [[55, 214], 0.013333333333333334, ['Coffee', 'Spice']],
#  [[61, 214], 0.013333333333333334, ['Cool', 'Spice']],
#  [[64, 214], 0.013333333333333334, ['Cotton Candy', 'Spice']],
#  [[71, 214], 0.013333333333333334, ['Dandelion', 'Spice']],
#  [[91, 214], 0.013333333333333334, ['Foxy', 'Spice']],
#  [[93, 214], 0.013333333333333334, ['Fresh', 'Spice']],
#  [[94, 214], 0.013333333333333334, ['Fried', 'Spice']],
#  [[99, 214], 0.013333333333333334, ['Garlic', 'Spice']],
#  [[104, 214], 0.013333333333333334, ['Grass', 'Spice']],
#  [[111, 214], 0.013333333333333334, ['Green Pepper', 'Spice']],
#  [[117, 214], 0.013333333333333334, ['Herb', 'Spice']],
#  [[118, 214], 0.013333333333333334, ['Honey', 'Spice']],
#  [[128, 214], 0.013333333333333334, ['Leather', 'Spice']],
#  [[140, 214], 0.013333333333333334, ['Maple', 'Spice']],
#  [[145, 214], 0.013333333333333334, ['Mint', 'Spice']],
#  [[152, 214], 0.013333333333333334, ['Must', 'Spice']],
#  [[154, 214], 0.013333333333333334, ['Nut', 'Spice']],
#  [[173, 214], 0.013333333333333334, ['Pepper', 'Spice']],
#  [[177, 214], 0.013333333333333334, ['Pine', 'Spice']],
#  [[188, 214], 0.013333333333333334, ['Radish', 'Spice']],
#  [[209, 214], 0.013333333333333334, ['Solvent', 'Spice']],
#  [[211, 214], 0.013333333333333334, ['Sour', 'Spice']],
#  [[214, 215], 0.013333333333333334, ['Spice', 'Stable']],
#  [[214, 219], 0.013333333333333334, ['Spice', 'Sulfur']],
#  [[214, 223], 0.013333333333333334, ['Spice', 'Thyme']],
#  [[214, 228], 0.013333333333333334, ['Spice', 'Tropical Fruit']],
#  [[214, 245], 0.013333333333333334, ['Spice', 'Wine']],
#  [[8, 95], 0.01126126126126126, ['Apricot', 'Fruit']],
#  [[95, 245], 0.01126126126126126, ['Fruit', 'Wine']],
#  [[16, 89], 0.011235955056179775, ['Banana', 'Floral']],
#  [[89, 93], 0.011235955056179775, ['Floral', 'Fresh']],
#  [[33, 106], 0.009852216748768473, ['Burnt', 'Green']],
#  [[55, 106], 0.009852216748768473, ['Coffee', 'Green']],
#  [[67, 106], 0.009852216748768473, ['Cucumber', 'Green']],
#  [[87, 106], 0.009852216748768473, ['Fish', 'Green']],
#  [[106, 137], 0.009852216748768473, ['Green', 'Malt']],
#  [[106, 145], 0.009852216748768473, ['Green', 'Mint']],
#  [[106, 181], 0.009852216748768473, ['Green', 'Polish']],
#  [[106, 211], 0.009852216748768473, ['Green', 'Sour']],
#  [[5, 95], 0.009009009009009009, ['Apple', 'Fruit']],
#  [[15, 95], 0.009009009009009009, ['Balsamic', 'Fruit']],
#  [[90, 95], 0.009009009009009009, ['Flower', 'Fruit']],
#  [[95, 118], 0.009009009009009009, ['Fruit', 'Honey']],
#  [[95, 168], 0.009009009009009009, ['Fruit', 'Peach']],
#  [[95, 214], 0.009009009009009009, ['Fruit', 'Spice']],
#  [[5, 89], 0.00749063670411985, ['Apple', 'Floral']],
#  [[8, 89], 0.00749063670411985, ['Apricot', 'Floral']],
#  [[22, 89], 0.00749063670411985, ['Bitter Almond', 'Floral']],
#  [[36, 89], 0.00749063670411985, ['Butter', 'Floral']],
#  [[41, 89], 0.00749063670411985, ['Caramel', 'Floral']],
#  [[48, 89], 0.00749063670411985, ['Cheese', 'Floral']],
#  [[89, 117], 0.00749063670411985, ['Floral', 'Herb']],
#  [[89, 130], 0.00749063670411985, ['Floral', 'Lemon']],
#  [[89, 157], 0.00749063670411985, ['Floral', 'Oil']],
#  ...]

# %%
row_labels.sort()
row_labels
col_labels.sort()
col_labels
df = pd.DataFrame(Xc.todense(), columns=row_labels, index=row_labels)
df
file_name = 'coocc_matrix.csv'
df.to_csv(file_name, sep='\t', encoding='utf-8')
#print(fema_terms)
flavours = pd.read_csv('coocc_matrix.csv',sep = '\t')
flavours.head()
var = flavours['acid'][88]
var

# %% [markdown]
# ###
